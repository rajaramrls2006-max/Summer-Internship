# %% [markdown]
# Uploading DataSet File directly from computer

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ae6dbf7-09c6-46bd-a564-105ed2da0355" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ae6dbf7-09c6-46bd-a564-105ed2da0355">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv("customers-100000.csv")

# %% [markdown]
# View the First Few Rows

# %%
df.head()
# Out:
#    Index      Customer Id First Name   Last Name                    Company  \
# 0      1  ffeCAb7AbcB0f07      Jared      Jarvis           Sanchez-Fletcher
# 1      2  b687FfC4F1600eC      Marie      Malone                  Mckay PLC
# 2      3  9FF9ACbc69dcF9c     Elijah     Barrera             Marks and Sons
# 3      4  b49edDB1295FF6E     Sheryl  Montgomery  Kirby, Vaughn and Sanders
# 4      5  3dcCbFEB17CCf2E     Jeremy     Houston             Lester-Manning
#
#              City                                       Country  \
# 0   Hatfieldshire                                       Eritrea
# 1  Robertsonburgh                                      Botswana
# 2         Kimbury                                      Barbados
# 3     Briannaview  Antarctica (the territory South of 60 deg S)
# 4   South Brianna                                    Micronesia
#
#                 Phone 1               Phone 2  \
# 0    274.188.8773x41185  001-215-760-4642x969
# ...

# %% [markdown]
# Check Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              100000 non-null  int64
#  1   Customer Id        100000 non-null  object
#  2   First Name         100000 non-null  object
#  3   Last Name          100000 non-null  object
#  4   Company            100000 non-null  object
#  5   City               100000 non-null  object
#  6   Country            100000 non-null  object
#  7   Phone 1            100000 non-null  object
#  8   Phone 2            100000 non-null  object
#  9   Email              100000 non-null  object
#  10  Subscription Date  100000 non-null  object
#  11  Website            100000 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 9.2+ MB

# %% [markdown]
# Check Dataset Information

# %%
df.shape
# Out:
# (100000, 12)

# %% [markdown]
# View Column Names

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %% [markdown]
# Generate Basic Statistics

# %%
df.describe()
# Out:
#                Index
# count  100000.000000
# mean    50000.500000
# std     28867.657797
# min         1.000000
# 25%     25000.750000
# 50%     50000.500000
# 75%     75000.250000
# max    100000.000000

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Phone 2              0
# Email                0
# Subscription Date    0
# Website              0
# dtype: int64

# %% [markdown]
# Select a Specific Column

# %%
df["Index"]
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
#           ...
# 99995     99996
# 99996     99997
# 99997     99998
# 99998     99999
# 99999    100000
# Name: Index, Length: 100000, dtype: int64

# %% [markdown]
# Filter Data

# %%
df[df["Country"] == "Botswana"]
# Out:
#        Index      Customer Id First Name Last Name  \
# 1          2  b687FfC4F1600eC      Marie    Malone
# 348      349  BBbc331AB8c6b03     Marcus    Hayden
# 865      866  dD9de5dCfd0a7b0   Kathleen   Hawkins
# 923      924  5a0aBdEe713c31B     Meagan     Leach
# 1265    1266  feec6E6a22F43aA      Patty  Bartlett
# ...      ...              ...        ...       ...
# 98875  98876  861401FaE90fC68    Katelyn     Glenn
# 98993  98994  7ff0A01A49C5BaC     Norman    Lester
# 99052  99053  c1896E26bcC80F9     Miguel       May
# 99197  99198  9fCebFBBd45DbeC  Francisco      Reid
# 99263  99264  2923d97b9Ad6c99    Shirley    Bailey
#
#                             Company            City   Country  \
# 1                         Mckay PLC  Robertsonburgh  Botswana
# 348          Morgan, Ho and Gilbert     Riversmouth  Botswana
# 865                     Wyatt Group    Anthonyhaven  Botswana
# 923    Mccormick, Foley and Rodgers       Kerriport  Botswana
# ...

# %% [markdown]
# Sort Data

# %%
df.sort_values("First Name")
# Out:
#        Index      Customer Id First Name  Last Name  \
# 86542  86543  3dfBd61de7b87dF      Aaron       York
# 59830  59831  370F734fCE57339      Aaron    Mcclain
# 29536  29537  ced2CdEcFb2255a      Aaron       Kirk
# 57966  57967  DF3D0B93B13aA8B      Aaron   Oconnell
# 48473  48474  ed825FB376A3D5c      Aaron     Hughes
# ...      ...              ...        ...        ...
# 67081  67082  7b9d9275D3DF7eF        Zoe  Wilkinson
# 78274  78275  e733adAb1eC8be8        Zoe   Valencia
# 87546  87547  9cb7EECd6868B8c        Zoe   Mckenzie
# 26169  26170  f7ade9d11477237        Zoe     Holmes
# 67171  67172  528D6ec3A21aedE        Zoe   Castillo
#
#                            Company               City                 Country  \
# 86542                Hart and Sons  West Faithchester                Portugal
# 59830              Faulkner-Campos        Hendrixfurt                  Malawi
# 29536               Campos-Barrett          Cortezton         Kyrgyz Republic
# ...

# %% [markdown]
# Count Records(Number of customers in each country)

# %%
df["Country"].value_counts()
# Out:
# Country
# Congo               835
# Korea               820
# Saudi Arabia        463
# Pitcairn Islands    456
# Saint Martin        453
#                    ...
# Moldova             371
# Jordan              365
# Saint Lucia         365
# Slovenia            361
# Greece              359
# Name: count, Length: 243, dtype: int64

# %% [markdown]
# Create a New Column(Full Name Column)

# %%
df["Full Name"] = df["First Name"] + " " + df["Last Name"]

# %%
df.head()
# Out:
#    Index      Customer Id First Name   Last Name                    Company  \
# 0      1  ffeCAb7AbcB0f07      Jared      Jarvis           Sanchez-Fletcher
# 1      2  b687FfC4F1600eC      Marie      Malone                  Mckay PLC
# 2      3  9FF9ACbc69dcF9c     Elijah     Barrera             Marks and Sons
# 3      4  b49edDB1295FF6E     Sheryl  Montgomery  Kirby, Vaughn and Sanders
# 4      5  3dcCbFEB17CCf2E     Jeremy     Houston             Lester-Manning
#
#              City                                       Country  \
# 0   Hatfieldshire                                       Eritrea
# 1  Robertsonburgh                                      Botswana
# 2         Kimbury                                      Barbados
# 3     Briannaview  Antarctica (the territory South of 60 deg S)
# 4   South Brianna                                    Micronesia
#
#                 Phone 1               Phone 2  \
# 0    274.188.8773x41185  001-215-760-4642x969
# ...

# %% [markdown]
# Find Unique Countries

# %%
df["Country"].unique()
# Out:
# array(['Eritrea', 'Botswana', 'Barbados',
#        'Antarctica (the territory South of 60 deg S)', 'Micronesia',
#        'Panama', 'United States of America', 'American Samoa',
#        'Saint Vincent and the Grenadines', 'Tanzania',
#        'Central African Republic', 'Falkland Islands (Malvinas)', 'Sudan',
#        'Faroe Islands', 'Bangladesh', 'Estonia', 'Venezuela', 'Nauru',
#        'Saint Kitts and Nevis', 'Ghana', 'San Marino', 'Yemen',
#        'Azerbaijan', 'Libyan Arab Jamahiriya', 'Saint Helena',
#        'Swaziland', 'Malaysia', 'Zambia', 'Korea', 'Uzbekistan',
#        "Lao People's Democratic Republic", 'Mongolia',
#        'Turks and Caicos Islands', 'Kenya', 'Tajikistan', 'Somalia',
#        'Bahamas', 'Samoa', 'Senegal', 'Isle of Man', 'Armenia',
#        'French Southern Territories', 'Taiwan', 'Tokelau', 'Slovenia',
#        'Bulgaria', 'Russian Federation', 'Spain', 'Burundi',
#        'Antigua and Barbuda', 'Niger', 'Greece', 'Timor-Leste', 'Romania',
# ...

# %% [markdown]
# Create Graph(Top 10 Countries by Customer Count)

# %%
import matplotlib.pyplot as plt
df["Country"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Countries")
plt.show()

# %% [markdown]
# Find Customers Added After 2021

# %%
df["Subscription Date"] = pd.to_datetime(df["Subscription Date"])

# %% [markdown]
# Export Modified Dataset

# %%
df.to_csv("customer_data_updated.csv", index=False)
